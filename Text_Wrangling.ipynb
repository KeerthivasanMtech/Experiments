# %% [markdown]
# # Install Dependencies

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# # Case Conversion

# %%
text = 'I am keerthivasn M.Tech data science student'
text
# Out:
# 'I am keerthivasn M.Tech data science student'

# %%
text.lower()
# Out:
# 'i am keerthivasn m.tech data science student'

# %%
text.upper()
# Out:
# 'I AM KEERTHIVASN M.TECH DATA SCIENCE STUDENT'

# %%
text.title()
# Out:
# 'I Am Keerthivasn M.Tech Data Science Student'

# %% [markdown]
# # Tokenization

# %%
sample_text = ("Dr. Avul Pakir Jainulabdeen Abdul Kalam, often referred to as A.P.J. Abdul Kalam, was an eminent Indian scientist, educator, and statesman who served as the 11th President of India from 2002 to 2007. He was born on October 15, 1931, in Rameswaram, Tamil Nadu, India, and passed away on July 27, 2015, in Shillong, Meghalaya, India.")
sample_text
# Out:
# 'Dr. Avul Pakir Jainulabdeen Abdul Kalam, often referred to as A.P.J. Abdul Kalam, was an eminent Indian scientist, educator, and statesman who served as the 11th President of India from 2002 to 2007. He was born on October 15, 1931, in Rameswaram, Tamil Nadu, India, and passed away on July 27, 2015, in Shillong, Meghalaya, India.'

# %%
import nltk

nltk.sent_tokenize(sample_text)
# Out:
# ['Dr. Avul Pakir Jainulabdeen Abdul Kalam, often referred to as A.P.J.',
#  'Abdul Kalam, was an eminent Indian scientist, educator, and statesman who served as the 11th President of India from 2002 to 2007.',
#  'He was born on October 15, 1931, in Rameswaram, Tamil Nadu, India, and passed away on July 27, 2015, in Shillong, Meghalaya, India.']

# %%
print(nltk.word_tokenize(sample_text))
# Out:
# ['Dr.', 'Avul', 'Pakir', 'Jainulabdeen', 'Abdul', 'Kalam', ',', 'often', 'referred', 'to', 'as', 'A.P.J', '.', 'Abdul', 'Kalam', ',', 'was', 'an', 'eminent', 'Indian', 'scientist', ',', 'educator', ',', 'and', 'statesman', 'who', 'served', 'as', 'the', '11th', 'President', 'of', 'India', 'from', '2002', 'to', '2007', '.', 'He', 'was', 'born', 'on', 'October', '15', ',', '1931', ',', 'in', 'Rameswaram', ',', 'Tamil', 'Nadu', ',', 'India', ',', 'and', 'passed', 'away', 'on', 'July', '27', ',', '2015', ',', 'in', 'Shillong', ',', 'Meghalaya', ',', 'India', '.']

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

text_spacy = nlp(sample_text)

# %%
[obj.text for obj in text_spacy.sents]
# Out:
# ['Dr. Avul Pakir Jainulabdeen Abdul Kalam, often referred to as A.P.J. Abdul Kalam, was an eminent Indian scientist, educator, and statesman who served as the 11th President of India from 2002 to 2007.',
#  'He was born on October 15, 1931, in Rameswaram, Tamil Nadu, India, and passed away on July 27, 2015, in Shillong, Meghalaya, India.']

# %%
print([obj.text for obj in text_spacy])
# Out:
# ['Dr.', 'Avul', 'Pakir', 'Jainulabdeen', 'Abdul', 'Kalam', ',', 'often', 'referred', 'to', 'as', 'A.P.J.', 'Abdul', 'Kalam', ',', 'was', 'an', 'eminent', 'Indian', 'scientist', ',', 'educator', ',', 'and', 'statesman', 'who', 'served', 'as', 'the', '11th', 'President', 'of', 'India', 'from', '2002', 'to', '2007', '.', 'He', 'was', 'born', 'on', 'October', '15', ',', '1931', ',', 'in', 'Rameswaram', ',', 'Tamil', 'Nadu', ',', 'India', ',', 'and', 'passed', 'away', 'on', 'July', '27', ',', '2015', ',', 'in', 'Shillong', ',', 'Meghalaya', ',', 'India', '.']

# %% [markdown]
# # Removing HTML tags & noise

# %%
import requests

data = requests.get('http://www.gutenberg.org/cache/epub/8001/pg8001.html')
content = data.text
print(content[2745:3948])
# Out:
# ne spacing ("leading") */
#     }
# body > p {
#     /* paras at <body> level - not in <div> or <table>  */
#     text-align: justify;
#     /* or left?? */
#     text-indent: 1em;
#     /* first-line indent */
#     }
# /* suppress indentation on paragraphs following heads  */
# h2 + p, h3 + p, h4 + p {
#     text-indent: 0
#     }
# /* tighter spacing for list item paragraphs */
# dd, li {
#     margin-top: 0.25em;
#     margin-bottom: 0;
#     line-height: 1.2em;
#     /* a bit closer than p's */
#     }
# /* ************************************************************************
#  * Head 2 is for chapter heads.
#  * ********************************************************************** */
# h2 {
#     /* text-align:center;  left-aligned by default. */
#     margin-top: 3em;
#     /* extra space above.. */
#     margin-bottom: 2em;
#     /* ..and below */
#     clear: both;
#     /* don't let sidebars overlap */
#     }
# /* ************************************************************************
#  * Head 3 is for main-topic heads.
#  * ********************************************************************** */
# h3 {
#     /* text-align:center;  left-aligned by default. */
#     margin-top: 2em;
#     /* extra space

# %%
import re
from bs4 import BeautifulSoup

def strip_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    [s.extract() for s in soup(['iframe', 'script'])]
    stripped_text = soup.get_text()
    stripped_text = re.sub(r'[\r|\n|\r\n]+', '\n', stripped_text)
    return stripped_text

clean_content = strip_html_tags(content)
print(clean_content[1163:1957])
# Out:
# oid; and darkness was
#            upon the face of the deep. And the Spirit of God moved upon
#            the face of the waters.
# 01:001:003 And God said, Let there be light: and there was light.
# 01:001:004 And God saw the light, that it was good: and God divided the
#            light from the darkness.
# 01:001:005 And God called the light Day, and the darkness he called
#            Night. And the evening and the morning were the first day.
# 01:001:006 And God said, Let there be a firmament in the midst of the
#            waters, and let it divide the waters from the waters.
# 01:001:007 And God made the firmament, and divided the waters which were
#            under the firmament from the waters which were above the
#            firmament: and it was so.
# 01:001:008 And God called the firmament H

# %% [markdown]
# # Removing Accented Characters

# %%
import unicodedata

def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

# %%
s = 'Sómě Áccěntěd těxt'
s
# Out:
# 'Sómě Áccěntěd těxt'

# %%
remove_accented_chars(s)
# Out:
# 'Some Accented text'

# %% [markdown]
# Removing Special Characters, Numbers and Symbols

# %%
import re

def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-Z0-9\s]' if not remove_digits else r'[^a-zA-Z\s]'
    text = re.sub(pattern, '', text)
    return text

# %%
s = "I am keerthivasan !!? !@#$%^🙂"
s
# Out:
# 'I am keerthivasan !!? !@#$%^🙂'

# %%
remove_special_characters(s, remove_digits=True)
# Out:
# 'I am keerthivasan  '

# %%
remove_special_characters(s)
# Out:
# 'I am keerthivasan  '

# %% [markdown]
# # Expanding Contractions

# %%
# !pip install contractions
# !pip install textsearch
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 7.6 MB/s eta 0:00:00
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.0.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 9.7 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.0.0 textsearch-0.0.24
# Requirement already satisfied: textsearch in /usr/local/lib/python3.10/dist-packages (0.0.24)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.10/dist-packages (from textsearch) (0.3.2)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.10/dist-packages (from textsearch) (2.0.0)

# %%
s = "Y'all can't expand contractions I'd think! You wouldn't be able to. How'd you do it?"
s
# Out:
# "Y'all can't expand contractions I'd think! You wouldn't be able to. How'd you do it?"

# %%
import contractions

list(contractions.contractions_dict.items())[:10]
# Out:
# [("I'm", 'I am'),
#  ("I'm'a", 'I am about to'),
#  ("I'm'o", 'I am going to'),
#  ("I've", 'I have'),
#  ("I'll", 'I will'),
#  ("I'll've", 'I will have'),
#  ("I'd", 'I would'),
#  ("I'd've", 'I would have'),
#  ('Whatcha', 'What are you'),
#  ("amn't", 'am not')]

# %%
contractions.fix(s)
# Out:
# 'You all cannot expand contractions I would think! You would not be able to. How did you do it?'

# %% [markdown]
# # Stemming

# %%
# Porter Stemmer
from nltk.stem import PorterStemmer
ps = PorterStemmer()

ps.stem('jumping'), ps.stem('jumps'), ps.stem('jumped')
# Out:
# ('jump', 'jump', 'jump')

# %%
ps.stem('lying')
# Out:
# 'lie'

# %%
ps.stem('strange')
# Out:
# 'strang'

# %% [markdown]
# # Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()

# %%
help(wnl.lemmatize)
# Out:
# Help on method lemmatize in module nltk.stem.wordnet:
#
# lemmatize(word: str, pos: str = 'n') -> str method of nltk.stem.wordnet.WordNetLemmatizer instance
#     Lemmatize `word` using WordNet's built-in morphy function.
#     Returns the input word unchanged if it cannot be found in WordNet.
#
#     :param word: The input word to lemmatize.
#     :type word: str
#     :param pos: The Part Of Speech tag. Valid options are `"n"` for nouns,
#         `"v"` for verbs, `"a"` for adjectives, `"r"` for adverbs and `"s"`
#         for satellite adjectives.
#     :param pos: str
#     :return: The lemma of `word`, for the given `pos`.

# %%
# lemmatize nouns
print(wnl.lemmatize('cars', 'n'))
print(wnl.lemmatize('boxes', 'n'))
# Out:
# car
# box

# %%
# lemmatize verbs
print(wnl.lemmatize('running', 'v'))
print(wnl.lemmatize('ate', 'v'))
# Out:
# run
# eat

# %%
# lemmatize adjectives
print(wnl.lemmatize('saddest', 'a'))
print(wnl.lemmatize('fancier', 'a'))
# Out:
# sad
# fancy

# %%
# ineffective lemmatization
print(wnl.lemmatize('ate', 'n'))
print(wnl.lemmatize('fancier', 'v'))
print(wnl.lemmatize('fancier'))
# Out:
# ate
# fancier
# fancier

# %%
s = 'I am keerthivasan '

# %% [markdown]
# ### Tokenize

# %%
tokens = nltk.word_tokenize(s)
print(tokens)
# Out:
# ['I', 'am', 'keerthivasan']

# %%
lemmatized_text = ' '.join(wnl.lemmatize(token) for token in tokens)
lemmatized_text
# Out:
# 'I am keerthivasan'

# %% [markdown]
# ### POS Tagging

# %%
tagged_tokens = nltk.pos_tag(tokens)
print(tagged_tokens)
# Out:
# [('I', 'PRP'), ('am', 'VBP'), ('keerthivasan', 'JJ')]

# %% [markdown]
# https://www.guru99.com/pos-tagging-chunking-nltk.html

# %% [markdown]
# ### Tag conversion to WordNet Tags

# %%
from nltk.corpus import wordnet

def pos_tag_wordnet(tagged_tokens):
    tag_map = {'j': wordnet.ADJ, 'v': wordnet.VERB, 'n': wordnet.NOUN, 'r': wordnet.ADV}
    new_tagged_tokens = [(word, tag_map.get(tag[0].lower(), wordnet.NOUN))
                            for word, tag in tagged_tokens]
    return new_tagged_tokens

# %%
wordnet_tokens = pos_tag_wordnet(tagged_tokens)
print(wordnet_tokens)
# Out:
# [('I', 'n'), ('am', 'v'), ('keerthivasan', 'a')]

# %% [markdown]
# ### Effective Lemmatization

# %%
lemmatized_text = ' '.join(wnl.lemmatize(word, tag) for word, tag in wordnet_tokens)
lemmatized_text
# Out:
# 'I be keerthivasan'

# %% [markdown]
# ### Your turn: Define a function such that you put all the above steps together so that it does the following
#
# - Function name is __`wordnet_lemmatize_text(...)`__
# - Input is a variable __`text`__ which should take in a document (bunch of words)
# - Call the earlier defined functions and utilize them
# - Return lemmatized text as the output (as a string)

# %%
wnl = WordNetLemmatizer()

def wordnet_lemmatize_text(text):
    tagged_tokens = nltk.pos_tag(nltk.word_tokenize(text))
    wordnet_tokens = pos_tag_wordnet(tagged_tokens)
    lemmatized_text = ' '.join(wnl.lemmatize(word, tag) for word, tag in wordnet_tokens)
    return lemmatized_text

# %% [markdown]
# ### Your Turn: Now call the function on the below sentence and test it

# %%
s
# Out:
# 'I am keerthivasan '

# %%
wordnet_lemmatize_text(s)
# Out:
# 'I be keerthivasan'

# %% [markdown]
# # Stopword Removal

# %%
def remove_stopwords(text, is_lower_case=False, stopwords=None):
    if not stopwords:
        stopwords = nltk.corpus.stopwords.words('english')
    tokens = nltk.word_tokenize(text)
    tokens = [token.strip() for token in tokens]

    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopwords]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopwords]

    filtered_text = ' '.join(filtered_tokens)
    return filtered_text

# %%
stop_words = nltk.corpus.stopwords.words('english')
print(stop_words[:10])
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
s ='Kalam began his career at the Indian Space Research Organisation (ISRO) in the 1960s'

# %%
remove_stopwords(s, is_lower_case=False)
# Out:
# 'Kalam began career Indian Space Research Organisation ( ISRO ) 1960s'

# %%
remove_stopwords(s, is_lower_case=False, stopwords=stop_words)
# Out:
# 'Kalam began career the Indian Space Research Organisation ( ISRO ) the 1960s'
